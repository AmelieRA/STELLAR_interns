# %%
#from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

stars = [176872276, 38461375, 150437065, 281631603, 348896748, 382517990, 38461205, 38462407, 55498515, 349194688]

# %%
for i in stars:
    tic = i
    flux = np.load('stitched_data/[{}]/flux.npy'.format(tic))
    time = np.load('stitched_data/[{}]/flux.npy'.format(tic))
    plt.plot(time,flux)   #{} replaced by the variable
