# %%
import detrender as dt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk
from astropy.table import Table
#if u can could em they r probs j outliers no mask fff

# %%
#star = [167126073]
#lc, stats = dt.detrend_data(star)
#print(lc)

# %%
#lc_idx = np.arange(0,len(lc),1)
#mytable = Table([lc_idx, stats[0],stats[1]], names =('lc_idx','star_id','sector'))
#mytable

# %%
star = [176872276]

# %%
lc, stats = dt.detrend_data(star)

# %%
len(lc)
# Out:
# 12

# %%
lc[0].scatter();
print(stats[1][1])
plt.axvline(1348.7, color = 'r', linestyle = '--')
plt.axvline(1349.3, color = 'r', linestyle = '--')
#the stats 1 gets the second column in the array i think and adding the zero tells the secotr, change the second brackets to specify thye sector
# Out:
# 2

# %%
lc[1].scatter();

# %%
lc[2].scatter();
print(stats[1][2])
plt.axvline(1394.7, color = 'r', linestyle = '--')
plt.axvline(1395.5, color = 'r', linestyle = '--')
# Out:
# 3

# %%
lc[3].scatter();
print(stats[1][3])
plt.axvline(1422.5, color = 'r', linestyle = '--')
plt.axvline(1423.6, color = 'r', linestyle = '--')
plt.axvline(1436.5, color = 'r', linestyle = '--')
plt.axvline(1437, color = 'r', linestyle = '--')
# Out:
# 4

# %%
lc[4].scatter();
print(stats[1][4])
plt.axvline(1490, color = 'r', linestyle = '--')
plt.axvline(1490.3, color = 'r', linestyle = '--')
# Out:
# 6

# %%
lc[5].scatter();
print(stats[1][5])
# Out:
# 7

# %%
lc[6].scatter();
print(stats[1][6])
plt.axvline(1518.15, color = 'r', linestyle = '--')
plt.axvline(1518.35, color = 'r', linestyle = '--')
# Out:
# 8

# %%
lc[7].scatter();
print(stats[1][7])
# Out:
# 9

# %%
lc[8].scatter();
print(stats[1][8])
# Out:
# 10

# %%
lc[9].scatter();
print(stats[1][9])
plt.axvline(1609.5, color = 'r', linestyle = '--')
plt.axvline(1609.8, color = 'r', linestyle = '--')
# Out:
# 11

# %%
lc[10].scatter();
print(stats[1][6])
plt.axvline(1609.5, color = 'r', linestyle = '--')
plt.axvline(1609.8, color = 'r', linestyle = '--')
# Out:
# 8

# %%
lc(11).scatter();
plt.axvline()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-75b29203fbc1> in <module>
# ----> 1 lc(11).scatter();
#       2 plt.axvline()
#
# TypeError: 'list' object is not callable

# %%
lc[12].scatter();

# %%
#import starspot
#class name():
    #def other functions
    #def name(self):
    
    
#plt.scatter(mydata)
#plt.show()
#need the show when in terminal
