# %%
import detrender as dt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk
from astropy.table import Table

# %%
star = [167126073]
lc, stats = dt.detrend_data(star)

# %%
len(lc)
# Out:
# 9

# %%
lc_idx = np.arange(0,len(lc),1)
mytable = Table([lc_idx, stats[0],stats[1]], names =('lc_idx','star_id','sector'))
mytable
# Out:
# <Table length=9>
# lc_idx  star_id  sector
# int64    int32   int32
# ------ --------- ------
#      0 167126073      4
#      1 167126073      5
#      2 167126073      6
#      3 167126073      7
#      4 167126073      8
#      5 167126073      9
#      6 167126073     10
#      7 167126073     12
#      8 167126073     13

# %%
lc[0].scatter();
print(stats[1][0])
plt.axvline(1436.5, color = 'r', linestyle = '--')
plt.axvline(1422.5, color = 'r', linestyle = '--')
plt.axvline(1423.65, color = 'r', linestyle = '--')
plt.axvline(1437, color = 'r', linestyle = '--')
# Out:
# 4

# %%
lc[1].scatter();
print(stats[1][1])
plt.axvline(1463.6, color = 'r', linestyle = '--')
plt.axvline(1464.5, color = 'r', linestyle = '--')
# Out:
# 5

# %%
lc[2].scatter();
print(stats[1][2])
# Out:
# 6

# %%
lc[3].scatter();
print(stats[1][3])
# Out:
# 7

# %%
lc[4].scatter();
print(stats[1][4])
plt.axvline(1517.3, color = 'r', linestyle = '--')
plt.axvline(1517.6, color = 'r', linestyle = '--')
# Out:
# 8

# %%
lc[5].scatter();
print(stats[1][5])
# Out:
# 9

# %%
lc[6].scatter();
print(stats[1][6])
# Out:
# 10

# %%
lc[7].scatter();
print(stats[1][7])
plt.axvline(1624.9, color = 'r', linestyle = '--')
plt.axvline(1626.5, color = 'r', linestyle = '--')
# Out:
# 12

# %%
lc[8].scatter();
print(stats[1][8])
# Out:
# 13

# %%
# glob glob wild card
