# %% [markdown]
# # _Matplotlib Review_

# %% [markdown]
# # _Run the following cells and see if you can figure out how the code is running to answer each question above the cell._

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Q-1: Why does the x-axis go to 3.0, but the y-axis goes to 4.0?
# ##### hint: look at the array you gave for plotting

# %%
#Becuase counting starts w 0, generated x axis aray to match the y

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
# copy the above code into this cell
#and make some changes to see how the output is affected

plt.plot([0, 1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# ## Q-2: What order is the default for plotting data?
# #### hint: x,y or y,x

# %%
#x,y

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
# copy the above code into this cell
#and make some changes to see how the output is affected

plt.plot([1, 4, 9, 16], [1, 2, 3, 4])

# %% [markdown]
# ## Q-3: What does 'ro' do?
# #### hint: try replacing 'ro' with 'b-'

# %%
#changes to a red circle, customizes display of graph

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# copy the above code into this cell
#and make some changes to see how the output is affected
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b-')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ## Q-4: What does the list inside plt.axis() do?
# #### hint: try changing one value at a time to see how the output changes

# %%
#defines x and y axis

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# copy the above code into this cell
#and make some changes to see how the output is affected

# %% [markdown]
# ## Q-5: Can you change the plot to have a black dotted line?
# #### hint: google 'matplotlib color string', then google 'matplotlib line style string'; use the top hits for both

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
# copy the above code into this cell
#and make the necessary changes

# %% [markdown]
# ## Q-6: Can you make the grid red and change the linewidth to 2?
# #### hint: google 'matplotlib grid', use the top hit that includes an example to also change linestyle to = '-'

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.grid(True,color='r')
plt.show()

# %%
# copy the above code into this cell
#and make the necessary changes

# %% [markdown]
# ## Q-7: How did the figure become bigger?
# #### hint: after figsize change the value order from 10,5 to 5,10 and rerun to see how that changes the output

# %%
mylist = [0,2,4,6,8,10]
myarray = np.array([1,3,5,7,9,11])

plt.figure(figsize=(10,5))
plt.plot(mylist,myarray)
plt.xlabel('mylist',c='g')
plt.ylabel('myarray',c='m')
plt.title('My Plot',fontsize=25)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-81757d3978c0> in <module>
#       4 plt.figure(figsize=(10,5))
#       5 plt.plot(mylist,myarray)
# ----> 6 plt.xlabel('mylist',c='g')
#       7 plt.ylabel('myarray',c='m')
#       8 plt.title('My Plot',fontsize=25)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, **kwargs)
#    3063 def xlabel(xlabel, fontdict=None, labelpad=None, **kwargs):
#    3064     return gca().set_xlabel(
# -> 3065         xlabel, fontdict=fontdict, labelpad=labelpad, **kwargs)
#    3066
#    3067
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     263         if labelpad is not None:
#     264             self.xaxis.labelpad = labelpad
# --> 265         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     266
#     267     def get_ylabel(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1565         if fontdict is not None:
#    1566             self.label.update(fontdict)
# -> 1567         self.label.update(kwargs)
#    1568         self.stale = True
#    1569         return self.label
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in update(self, kwargs)
#     185         sentinel = object()  # bbox can be None, so use another sentinel.
#     186         bbox = kwargs.pop("bbox", sentinel)
# --> 187         super().update(kwargs)
#     188         if bbox is not sentinel:
#     189             self.set_bbox(bbox)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     910                 func = getattr(self, 'set_' + k, None)
#     911                 if not callable(func):
# --> 912                     raise AttributeError('Unknown property %s' % k)
#     913                 return func(v)
#     914
#
# AttributeError: Unknown property c

# %%
# copy the above code into this cell
#and make some changes to see how the output is affected

# %% [markdown]
# # _Examine the code from each question's cell and name one new thing  you learned that is NOT directly related to the question asked about it._
