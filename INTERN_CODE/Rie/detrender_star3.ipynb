# %%
import detrender as dt
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk
from astropy.table import Table
star = [350619392]
lc, stats = dt.detrend_data(star)
lc_idx = np.arange(0,len(lc),1)
mytable = Table([lc_idx, stats[0],stats[1]], names =('lc_idx','star_id','sector'))
mytable
# Out:
# ...
# <Table length=12>
# lc_idx  star_id  sector
# int64    int32   int32
# ------ --------- ------
#      0 350619392      1
#      1 350619392      2
#      2 350619392      3
#      3 350619392      4
#      4 350619392      5
#      5 350619392      6
#      6 350619392      7
#      7 350619392      8
#      8 350619392     10
#      9 350619392     11
#     10 350619392     12
#     11 350619392     13

# %%
lc[0].scatter();
print(stats[1][0])
plt.axvline(1348, color = 'r', linestyle = '--')
plt.axvline(1349.6, color = 'r', linestyle = '--')
# Out:
# 1

# %%
lc[1].scatter();
print(stats[1][1])
# Out:
# 2

# %%
lc[2].scatter();
print(stats[1][2])
# Out:
# 3

# %%
lc[3].scatter();
print(stats[1][3])
plt.axvline(1436.2, color = 'r', linestyle = '--')
plt.axvline(1437, color = 'r', linestyle = '--')
# Out:
# 4

# %%
lc[4].scatter();
print(stats[1][4])
plt.axvline(1464, color = 'r', linestyle = '--')
plt.axvline(1464.5, color = 'r', linestyle = '--')
# Out:
# 5

# %%
lc[5].scatter();
print(stats[1][5])
# Out:
# 6

# %%
lc[6].scatter();
print(stats[1][6])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 7

# %%
lc[7].scatter();
print(stats[1][7])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 8

# %%
lc[8].scatter();
print(stats[1][8])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 10

# %%
lc[9].scatter();
print(stats[1][9])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 11

# %%
lc[10].scatter();
print(stats[1][10])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 12

# %%
lc[11].scatter();
print(stats[1][11])
#plt.axvline(, color = 'r', linestyle = '--')
#plt.axvline(, color = 'r', linestyle = '--')
# Out:
# 13
